# %% [markdown]
# <a href="https://colab.research.google.com/github/karloxkronfeld/Banderas/blob/master/INvestpyInformacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install investpy

# %%
import investpy

# %%
stock_names= investpy.get_stocks_list()

# %%
len(stock_names)
# Out:
# 39952

# %%
{idx:stock for idx, stock in enumerate(stock_names) if stock=="BBVA"}
# Out:
# {2586: 'BBVA', 3155: 'BBVA', 5126: 'BBVA', 8334: 'BBVA', 13511: 'BBVA'}

# %%
investpy.search_stocks(by="name",value="colombia")
# Out:
#     country                                      name  ... currency  symbol
# 0    canada                        Gran Colombia Gold  ...      CAD     GCM
# 1  colombia                                Colombiana  ...      COP     CFV
# 2  colombia                                 Bcolombia  ...      COP     BIC
# 3  colombia              Bolsa De Valores De Colombia  ...      COP     BVC
# 4  colombia                            Bancolombia Pf  ...      COP  BIC_p1
# 5  colombia         Corporacion Financiera Colombiana  ...      COP   CFV_p
# 6  colombia                       Enka de Colombia SA  ...      COP     ENK
# 7  colombia  Banco Bilbao Vizcaya Argentaria Colombia  ...      COP     BGA
# 8  colombia                        Carton de Colombia  ...      COP     CRT
# 9   germany                               BanColombia  ...      EUR    BICy
#
# [10 rows x 6 columns]

# %%
investpy.search_funds(by="name",value="ishares")
# Out:
#            country  ...     underlying
# 0        australia  ...            NaN
# 1        australia  ...            NaN
# 2        australia  ...            NaN
# 3        australia  ...            NaN
# 4           brazil  ...            NaN
# ..             ...  ...            ...
# 175  united states  ...            NaN
# 176  united states  ...            NaN
# 177  united states  ...            NaN
# 178  united states  ...            NaN
# 179  united states  ...  MSCI EAFE Net
#
# [180 rows x 8 columns]

# %%
investpy.get_etf_information(etf="SPDR Gold MiniShares",country="united states", as_json=True)
# Out:
# {'1-Year Change': '3.68%',
#  '52 wk Range': '16.65 - 20.62',
#  'Asset Class': 'Commodity',
#  'Average Vol. (3m)': 2560453.0,
#  'Beta': None,
#  'Dividend Yield': None,
#  'Dividends (TTM)': None,
#  'ETF Name': 'SPDR Gold MiniShares',
#  'Market Cap': None,
#  'Open': 17.79,
#  'Prev. Close': 17.75,
#  'ROI (TTM)': None,
#  'Shares Outstanding': None,
#  'Todays Range': '17.62 - 17.78',
#  'Total Assets': None,
#  'Volume': 798679.0}

# %%
investpy.get_stock_recent_data("AMZN","united states")
# Out:
#                Open     High      Low    Close   Volume Currency
# Date
# 2021-03-23  3127.00  3181.20  3122.81  3137.50  3817263      USD
# 2021-03-24  3149.00  3160.31  3085.86  3087.07  2958981      USD
# 2021-03-25  3068.24  3108.09  3039.10  3046.26  3563469      USD
# 2021-03-26  3044.06  3056.66  2996.00  3052.03  3312924      USD
# 2021-03-29  3053.29  3090.28  3028.71  3075.73  2745968      USD
# 2021-03-30  3068.99  3069.66  3034.70  3055.29  2337603      USD
# 2021-03-31  3067.57  3118.94  3065.82  3094.08  3093896      USD
# 2021-04-01  3117.94  3162.44  3115.55  3161.00  2940318      USD
# 2021-04-05  3173.00  3235.39  3161.37  3226.73  3334882      USD
# 2021-04-06  3222.72  3247.11  3217.82  3223.82  2537809      USD
# 2021-04-07  3233.08  3303.44  3223.76  3279.39  3346227      USD
# 2021-04-08  3310.90  3324.50  3292.00  3299.30  2812090      USD
# 2021-04-09  3304.70  3372.20  3288.90  3372.20  4341473      USD
# ...

# %%
investpy.get_stock_historical_data("AMZN","united states","01/01/2010","22/04/2021")
# Out:
#                Open     High      Low    Close    Volume Currency
# Date
# 2010-01-04   136.25   136.61   133.14   133.90   7600543      USD
# 2010-01-05   133.43   135.48   131.81   134.69   8856456      USD
# 2010-01-06   134.60   134.73   131.65   132.25   7180977      USD
# 2010-01-07   132.01   132.32   128.80   130.00  11030124      USD
# 2010-01-08   130.56   133.68   129.03   133.52   9833829      USD
# ...             ...      ...      ...      ...       ...      ...
# 2021-04-16  3380.00  3406.80  3355.59  3399.44   3186049      USD
# 2021-04-19  3390.07  3434.94  3360.16  3372.01   2725405      USD
# 2021-04-20  3372.03  3381.31  3316.37  3334.69   2623032      USD
# 2021-04-21  3321.80  3362.39  3306.00  3362.02   2211166      USD
# 2021-04-22  3369.79  3371.32  3302.00  3309.04   2580590      USD
#
# [2846 rows x 6 columns]

# %%
investpy.get_stock_dividends("bbva","spain")
# Out:
#          Date  Dividend                    Type Payment Date  Yield
# 0  2020-04-07    0.1600  trailing_twelve_months   2020-04-09  6.07%
# 1  2019-10-11    0.2600  trailing_twelve_months   2019-10-15  4.97%
# 2  2019-04-08    0.2600  trailing_twelve_months   2019-04-10  5.53%
# 3  2018-06-11    0.3839  trailing_twelve_months   2018-06-13  3.96%
# 4  2018-04-06    0.2400  trailing_twelve_months   2018-04-10  4.41%
# 5  2017-10-06    0.3786  trailing_twelve_months   2017-10-10  4.45%
# 6  2017-04-03    0.3663  trailing_twelve_months   2017-04-26  4.88%
# 7  2017-01-10    0.3663  trailing_twelve_months   2017-01-12  5.35%
# 8  2016-10-03    0.3638  trailing_twelve_months   2016-10-26  5.58%
# 9  2016-07-06    0.3662  trailing_twelve_months   2016-07-11  6.83%
# 10 2016-04-05    0.3640  trailing_twelve_months   2016-04-27  6.52%
# 11 2016-01-12    0.3680  trailing_twelve_months   2016-01-12  6.00%

# %%
investpy.get_stock_historical_data("EC","united states","01/01/2016","22/04/2021").Close.plot()

# %%
investpy.get_stock_dividends("EC","united states")
# Out:
#          Date  Dividend                    Type Payment Date   Yield
# 0  2021-04-20  0.981000                  annual   2021-04-29   7.84%
# 1  2020-04-21  0.887800                  annual   2020-05-01   6.92%
# 2  2019-12-26  1.388000  trailing_twelve_months   2020-01-02  12.44%
# 3  2019-04-23  1.388000                  annual   2019-05-03   7.10%
# 4  2018-04-17  0.644100                  annual   2018-04-27   2.98%
# 5  2017-04-25  0.155700                  annual   2017-05-08   0.79%
# 6  2015-06-17  1.039700  trailing_twelve_months   2015-06-30  14.87%
# 7  2014-04-22  2.646040  trailing_twelve_months   2014-05-12       -
# 8  2013-04-09  3.205690  trailing_twelve_months   2013-04-23       -
# 9  2012-04-19  3.409940  trailing_twelve_months   2012-05-09       -
# 10 2011-10-07  0.537513  trailing_twelve_months   2011-11-02       -
# 11 2011-07-08  0.539798  trailing_twelve_months   2011-08-02       -
# 12 2011-04-07  0.523859  trailing_twelve_months   2011-05-03       -
# ...

# %%
investpy.get_currency_cross_historical_data("XAU/USD","01/01/2000","22/04/2021",interval="Daily")
# Out:
#                Open     High      Low    Close Currency
# Date
# 2000-01-03   288.50   289.00   289.00   289.00      USD
# 2000-01-04   288.75   282.45   282.45   282.45      USD
# 2000-01-05   281.50   281.00   281.00   281.00      USD
# 2000-01-06   280.12   281.23   281.23   281.23      USD
# 2000-01-07   281.15   281.75   281.75   281.75      USD
# ...             ...      ...      ...      ...      ...
# 2021-04-16  1763.84  1784.07  1759.79  1776.31      USD
# 2021-04-19  1779.50  1790.54  1765.98  1769.31      USD
# 2021-04-20  1770.30  1780.77  1763.18  1777.25      USD
# 2021-04-21  1778.64  1797.98  1775.95  1793.46      USD
# 2021-04-22  1794.15  1798.29  1776.83  1783.94      USD
#
# [5548 rows x 5 columns]

# %%
investp
